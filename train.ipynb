# %%
# !pip install mtcnn
# Out:
# Collecting mtcnn
#   Downloading mtcnn-1.0.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: joblib>=1.4.2 in d:\annacoda\lib\site-packages (from mtcnn) (1.4.2)
# Collecting lz4>=4.3.3 (from mtcnn)
#   Downloading lz4-4.4.3-cp312-cp312-win_amd64.whl.metadata (3.9 kB)
# Downloading mtcnn-1.0.0-py3-none-any.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --------------------------- ------------ 1.3/1.9 MB 11.2 MB/s eta 0:00:01
#    --------------------------- ------------ 1.3/1.9 MB 11.2 MB/s eta 0:00:01
#    -------------------------------------- - 1.8/1.9 MB 3.0 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 3.0 MB/s eta 0:00:00
# Downloading lz4-4.4.3-cp312-cp312-win_amd64.whl (99 kB)
# Installing collected packages: lz4, mtcnn
#   Attempting uninstall: lz4
#     Found existing installation: lz4 4.3.2
#     Uninstalling lz4-4.3.2:
#       Successfully uninstalled lz4-4.3.2
# Successfully installed lz4-4.4.3 mtcnn-1.0.0
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import os
import json
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from tqdm import tqdm
from mtcnn import MTCNN
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split

# Định nghĩa đường dẫn
DATASET_PATH = "D:/Study/Programming/DPL/dfdc_train_part_00/dfdc_train_part_0"  # Cập nhật đường dẫn thực tế
SAVE_PATH = "D:/Study/Programming/DPL/dfdc_train_part_00/image after detect"
METADATA_PATH = os.path.join(DATASET_PATH, "metadata.json")

# Đọc metadata
with open(METADATA_PATH, 'r') as f:
    metadata = json.load(f)

# Chuẩn bị danh sách video và nhãn
video_labels = []
for video, details in metadata.items():
    video_path = os.path.join(DATASET_PATH, video)
    label = 1 if details["label"] == "FAKE" else 0
    video_labels.append((video_path, label))

df = pd.DataFrame(video_labels, columns=["video_path", "label"])

# %%
# Hàm trích xuất 32 frames cách đều nhau từ video
def extract_frames(video_path, num_frames=32):
    cap = cv2.VideoCapture(video_path)
    total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
    frame_ids = np.linspace(0, total_frames - 1, num_frames, dtype=int)
    frames = []
    for frame_id in frame_ids:
        cap.set(cv2.CAP_PROP_POS_FRAMES, frame_id)
        ret, frame = cap.read()
        if ret:
            frames.append(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
    cap.release()
    return frames

# MTCNN face detection
detector = MTCNN()

def detect_face(image, margin=0.3):
    faces = detector.detect_faces(image)
    if faces:
        x, y, w, h = faces[0]['box']
        x -= int(w * margin)
        y -= int(h * margin)
        w = int(w * (1 + 2 * margin))
        h = int(h * (1 + 2 * margin))
        return image[max(0, y):y + h, max(0, x):x + w]
    return None

# Chuẩn bị dữ liệu hình ảnh
image_data = []
labels = []

# %%
for index, row in tqdm(df.iterrows(), total=len(df), desc="Processing videos"):
    video_name = os.path.splitext(os.path.basename(row["video_path"]))[0]
    frames = extract_frames(row["video_path"])
    for frame_number, frame in enumerate(frames):
        face = detect_face(frame)
        if face is not None:
            face = cv2.resize(face, (224, 224))
            image_data.append(face)
            labels.append(row["label"])
            
            # Lưu ảnh sau khi detect
            save_dir = os.path.join(SAVE_PATH, video_name, str(frame_number))
            os.makedirs(save_dir, exist_ok=True)
            save_path = os.path.join(save_dir, "face.jpg")
            cv2.imwrite(save_path, cv2.cvtColor(face, cv2.COLOR_RGB2BGR))

# %%
import numpy as np
import json
import os
import tensorflow as tf
from sklearn.model_selection import train_test_split

# Định nghĩa đường dẫn dữ liệu
data_dir = "D:\\Study\\Programming\\DPL\\dfdc_train_part_00\\image after detect\\"
metadata_path = "C:\\Users\\vpmx5\\Downloads\\Presentation DPL PRJ 1\\new_metadata.json"

# Đọc metadata để lấy nhãn
with open(metadata_path, "r") as f:
    metadata = json.load(f)

image_paths = []
labels = []

# Duyệt qua từng video folder
video_folders = os.listdir(data_dir)
for video_name in video_folders:
    video_path = os.path.join(data_dir, video_name)

    # Bỏ qua nếu không phải thư mục
    if not os.path.isdir(video_path):
        continue

    print ( metadata.get(video_name + ".mp4", {}) )
    # Xác định nhãn (fake = 1, real = 0)
    label = 1 if metadata.get(video_name + ".mp4", {}).get("label") == "REAL" else 0

    # Duyệt qua từng frame trong thư mục
    for frame_file in os.listdir(video_path):
        frame_path = os.path.join(video_path, frame_file, "face.jpg")  # Đường dẫn đúng

        if os.path.exists(frame_path):  # Kiểm tra file tồn tại trước khi thêm vào danh sách
            image_paths.append(frame_path)
            labels.append(label)

# Chia train/test
train_paths, test_paths, train_labels, test_labels = train_test_split(
    image_paths, labels, test_size=0.3, random_state=42
)

# Hàm load ảnh từ đường dẫn
def load_and_preprocess(image_path, label):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_jpeg(image, channels=3)
    image = tf.image.resize(image, [224, 224])
    image = image / 255.0  # Chuẩn hóa ảnh về [0,1]
    return image, label

# Tạo tf.data.Dataset với lazy loading
train_dataset = tf.data.Dataset.from_tensor_slices((train_paths, train_labels))
train_dataset = train_dataset.map(load_and_preprocess).batch(16).shuffle(1000).prefetch(tf.data.AUTOTUNE)

test_dataset = tf.data.Dataset.from_tensor_slices((test_paths, test_labels))
test_dataset = test_dataset.map(load_and_preprocess).batch(16).prefetch(tf.data.AUTOTUNE)
# Out:
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fzvpbrzssi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybnucgidtu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ljuuovfkgi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'knxltsvzyu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xugmhbetrw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hicjuubiau.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnhkjhyhvw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lokzwdldxp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'doniqevxeg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gvasarkpfh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fzvpbrzssi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xugmhbetrw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xugmhbetrw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnhkjhyhvw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hsbwhlolsn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xmkwsnuzyq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xchzardbfa.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ljuuovfkgi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ddtbarpcgo.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'onbgbghesu.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'onbgbghesu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ldtgofdaqg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'heiyoojifp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wcqvzujamg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gvasarkpfh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rnpefxwptv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ddtbarpcgo.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybnucgidtu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dhjnjkzuhq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xmkwsnuzyq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybnucgidtu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'knxltsvzyu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ddtbarpcgo.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'knxltsvzyu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'heiyoojifp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yljecirelf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ljuuovfkgi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xchzardbfa.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xchzardbfa.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rnpefxwptv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnhkjhyhvw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eiwtggvtfp.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'didzujjhtg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apedduehoy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wcqvzujamg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prmwoaeeng.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ucthmsajay.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hicjuubiau.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gcdtglsoqj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rnpefxwptv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ldtgofdaqg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rnpefxwptv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'onbgbghesu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'doniqevxeg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gvasarkpfh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'heiyoojifp.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vokrpfjpeb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fzvpbrzssi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fzvpbrzssi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rnpefxwptv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xmkwsnuzyq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yljecirelf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yljecirelf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rmufsuogzn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xmkwsnuzyq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prmwoaeeng.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wcqvzujamg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gvasarkpfh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'didzujjhtg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ucthmsajay.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jvtjxreizj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prmwoaeeng.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xchzardbfa.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ddtbarpcgo.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ngvcqxjhyb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hicjuubiau.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yljecirelf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ldtgofdaqg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ddtbarpcgo.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybnucgidtu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prmwoaeeng.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rnpefxwptv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ldtgofdaqg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dhjnjkzuhq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ucthmsajay.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnjkpdviqb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xmkwsnuzyq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rmufsuogzn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rmuxlgsedw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fgobmbcami.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yexeazbqig.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ldtgofdaqg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dhjnjkzuhq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prmwoaeeng.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lsmnqsnqld.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ldtgofdaqg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'knxltsvzyu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lokzwdldxp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eiwtggvtfp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hicjuubiau.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xugmhbetrw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yexeazbqig.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ddtbarpcgo.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lokzwdldxp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnjkpdviqb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'doniqevxeg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'knxltsvzyu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hplxtssgnz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ngvcqxjhyb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rmufsuogzn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ucthmsajay.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnjkpdviqb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ljuuovfkgi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xugmhbetrw.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sylnrepacf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ljuuovfkgi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rmufsuogzn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'heiyoojifp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sylnrepacf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yexeazbqig.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yljecirelf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fzvpbrzssi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# ...
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gvasarkpfh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xugmhbetrw.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'doniqevxeg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hicjuubiau.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ddtbarpcgo.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'doniqevxeg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yexeazbqig.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prmwoaeeng.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnhkjhyhvw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prdrkaxeob.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yljecirelf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lokzwdldxp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eiwtggvtfp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dhjnjkzuhq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ucthmsajay.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'srfefmyjvt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gvasarkpfh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xmkwsnuzyq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xchzardbfa.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hsbwhlolsn.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fzvpbrzssi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'heiyoojifp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wcqvzujamg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xchzardbfa.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'chqqxfuuzi.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apedduehoy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xugmhbetrw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wcqvzujamg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hicjuubiau.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'upmgtackuf.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnhkjhyhvw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'yxvmusxvcz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exseruhiuk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'apvzjkvnwn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'doniqevxeg.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnhkjhyhvw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xmkwsnuzyq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybnucgidtu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ldtgofdaqg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'didzujjhtg.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'doniqevxeg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gnmmhlbzge.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qyqufaskjs.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nweufafotd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wclvkepakb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eiwtggvtfp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vmxfwxgdei.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'prmwoaeeng.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nhsijqpoda.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'ybbrkacebd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jzupayeuln.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'knxltsvzyu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xcruhaccxc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wcqvzujamg.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xkfliqnmwt.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fdpisghkmd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lzbmwwejxb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'knxltsvzyu.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hsbwhlolsn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'qarqtkvgby.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'REAL', 'split': 'train'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xdezcezszc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'khtwrijuqn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fzvpbrzssi.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xcruhaccxc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'nrnklcxdzq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vtunvalyji.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'syxobtuucp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wfzjxzhdkj.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'lnjkpdviqb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dxfdovivlw.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uprwuohbwx.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'sttnfyptum.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jawgcggquk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'gvasarkpfh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'eppyqpgewp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'exxqlfpnbz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'hivnldfvyl.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'uqtqhiqymz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'heiyoojifp.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'xjzkfqddyk.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'kqlvggiqee.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fopjiyxiqd.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'psjfwjzrrh.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'jytrvwlewz.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dhjnjkzuhq.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'wynotylpnm.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'dpevefkefv.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'rktrpsdlci.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fsaronfupy.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'aayrffkzxn.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'pqdeutauqc.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fufcmupzen.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'vpmyeepbep.mp4'}
# {'label': 'FAKE', 'split': 'train', 'original': 'fnslimfagb.mp4'}

# %%
set(train_labels)
# Out:
# {0, 1}

# %%
from tensorflow.keras.metrics import AUC


# Xây dựng mô hình dựa trên EfficientNetB0
base_model = EfficientNetB0(weights="imagenet", include_top=False, input_shape=(224, 224, 3))
x = GlobalAveragePooling2D()(base_model.output)
x = Dense(128, activation="relu")(x)
out = Dense(1, activation="sigmoid")(x)
model = Model(inputs=base_model.input, outputs=out)

# Compile mô hình
model.compile(optimizer=Adam(learning_rate=0.0001), loss="binary_crossentropy", metrics=[AUC(curve="PR")])

# %%
model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=1,
    verbose=1  # 0: Không hiển thị, 1: Mặc định, 2: Rút gọn
)
# Out:
# 1812/1812 ━━━━━━━━━━━━━━━━━━━━ 3107s 2s/step - auc_1: 0.4933 - loss: 0.1670 - val_auc_1: 0.0673 - val_loss: 3.5952

# %%
MODEL_SAVE_PATH = "C:\\Users\\vpmx5\\Downloads\\Presentation DPL PRJ 1\\dfdc_model.h5"
model.save(MODEL_SAVE_PATH)
print(f"Model saved at {MODEL_SAVE_PATH}")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# Model saved at C:\Users\vpmx5\Downloads\Presentation DPL PRJ 1\dfdc_model.h5

# %%
# Dự đoán trên tập test
y_true = []
y_pred = []
y_scores = []

for images, labels in test_dataset:
    predictions = model.predict(images)
    predicted_labels = (predictions >= 0.5).astype(int).flatten()
    
    y_true.extend(labels.numpy())
    y_pred.extend(predicted_labels)
    y_scores.extend(predictions.flatten())

# Đánh giá mô hình
from sklearn.metrics import classification_report, accuracy_score
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 281ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 282ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 283ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 350ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 284ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 339ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 337ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 341ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 359ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 357ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 343ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 287ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 363ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 345ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 352ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 390ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 362ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 336ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 289ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 338ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 351ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 290ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 354ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 356ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 312ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 342ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 330ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 414ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 348ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 364ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 377ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 346ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 353ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 310ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 349ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 370ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step

# %%
print("Accuracy:", accuracy_score(y_true, y_pred))
# Out:
# Accuracy: 0.9336874295831321
